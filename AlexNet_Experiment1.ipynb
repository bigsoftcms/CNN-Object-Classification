# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f1b211fc-9467-48fe-8917-19f96de36f97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1b211fc-9467-48fe-8917-19f96de36f97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.optimizers import SGD
from keras.layers import Dense, Activation, Dropout, Flatten,\
 Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization



# Initialising the CNN
classifier = Sequential()

# 1st Convolutional Layer
classifier.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(9, 9),\
 strides=(4,4), padding='valid'))
classifier.add(Activation('relu'))
# Pooling 
classifier.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation before passing it to the next layer
classifier.add(BatchNormalization())

# 2nd Convolutional Layer
classifier.add(Conv2D(filters=256, kernel_size=(7,7), strides=(1,1), padding='valid'))
classifier.add(Activation('relu'))
# Pooling
classifier.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
classifier.add(BatchNormalization())

# 3rd Convolutional Layer
classifier.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
classifier.add(Activation('relu'))
# Batch Normalisation
classifier.add(BatchNormalization())

# 4th Convolutional Layer
classifier.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
classifier.add(Activation('relu'))
# Batch Normalisation
classifier.add(BatchNormalization())

# 5th Convolutional Layer
classifier.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
classifier.add(Activation('relu'))
# Pooling
classifier.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
classifier.add(BatchNormalization())

# Passing it to a dense layer
classifier.add(Flatten())
# 1st Dense Layer
classifier.add(Dense(4096))
classifier.add(Activation('relu'))
# Add Dropout to prevent overfitting
classifier.add(Dropout(0.4))
# Batch Normalisation
classifier.add(BatchNormalization())

# 2nd Dense Layer
classifier.add(Dense(4096))
classifier.add(Activation('relu'))
# Add Dropout
classifier.add(Dropout(0.4))
# Batch Normalisation
classifier.add(BatchNormalization())

# Output Layer
classifier.add(Dense(5))
classifier.add(Activation('softmax'))

# Compiling the CNN
opt = SGD(lr=0.0005)
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# Part 2 - Fitting the CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('/content/drive/My Drive/Colab Notebooks/Object Classification/Training Set',
                                                 target_size = (224, 224),
                                                 batch_size = 10)

test_set = test_datagen.flow_from_directory('/content/drive/My Drive/Colab Notebooks/Object Classification/Test Set',
                                            target_size = (224, 224),
                                            batch_size = 10)
classifier.summary()
model = classifier.fit_generator(training_set,
                         steps_per_epoch = 1000,
                         epochs = 15,
                         validation_data = test_set,    
                         validation_steps = 100)

classifier.save("/content/drive/My Drive/Colab Notebooks/Object Classification/AlexNetAdammodel.h5")
print("Saved model to disk")
# Out:
# Found 426 images belonging to 5 classes.
# Found 125 images belonging to 5 classes.
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 54, 54, 96)        23424
# _________________________________________________________________
# activation_25 (Activation)   (None, 54, 54, 96)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 27, 27, 96)        0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 27, 27, 96)        384
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 21, 21, 256)       1204480
# _________________________________________________________________
# activation_26 (Activation)   (None, 21, 21, 256)       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 10, 256)       0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 10, 10, 256)       1024
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 384)         885120
# _________________________________________________________________
# activation_27 (Activation)   (None, 8, 8, 384)         0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 8, 8, 384)         1536
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 6, 6, 384)         1327488
# _________________________________________________________________
# activation_28 (Activation)   (None, 6, 6, 384)         0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 6, 6, 384)         1536
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 4, 4, 256)         884992
# _________________________________________________________________
# activation_29 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 4096)              4198400
# _________________________________________________________________
# activation_30 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_11 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# activation_31 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 20485
# _________________________________________________________________
# activation_32 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 25,363,973
# Trainable params: 25,344,837
# Non-trainable params: 19,136
# _________________________________________________________________
# Epoch 1/15
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 1000/1000 [==============================] - 1473s 1s/step - loss: 1.8345 - accuracy: 0.4608 - val_loss: 0.7180 - val_accuracy: 0.5959
# Epoch 2/15
# 1000/1000 [==============================] - 1457s 1s/step - loss: 1.4054 - accuracy: 0.5888 - val_loss: 1.1631 - val_accuracy: 0.6844
# Epoch 3/15
# 1000/1000 [==============================] - 1465s 1s/step - loss: 1.0912 - accuracy: 0.6869 - val_loss: 1.3105 - val_accuracy: 0.6635
# Epoch 4/15
# 1000/1000 [==============================] - 1490s 1s/step - loss: 0.8712 - accuracy: 0.7488 - val_loss: 1.5242 - val_accuracy: 0.7140
# Epoch 5/15
# 1000/1000 [==============================] - 1513s 2s/step - loss: 0.6400 - accuracy: 0.8188 - val_loss: 2.6217 - val_accuracy: 0.7698
# Epoch 6/15
# 1000/1000 [==============================] - 1552s 2s/step - loss: 0.5694 - accuracy: 0.8446 - val_loss: 0.4234 - val_accuracy: 0.8375
# Epoch 7/15
# 1000/1000 [==============================] - 1543s 2s/step - loss: 0.4460 - accuracy: 0.8784 - val_loss: 2.5664 - val_accuracy: 0.7689
# Epoch 8/15
# 1000/1000 [==============================] - 1551s 2s/step - loss: 0.4341 - accuracy: 0.8899 - val_loss: 2.7116 - val_accuracy: 0.7406
# Epoch 9/15
# 1000/1000 [==============================] - 1543s 2s/step - loss: 0.3578 - accuracy: 0.9077 - val_loss: 0.9093 - val_accuracy: 0.8115
# Epoch 10/15
# 1000/1000 [==============================] - 1519s 2s/step - loss: 0.3817 - accuracy: 0.9070 - val_loss: 0.0459 - val_accuracy: 0.8570
# Epoch 11/15
# 1000/1000 [==============================] - 1491s 1s/step - loss: 0.3194 - accuracy: 0.9195 - val_loss: 1.5923 - val_accuracy: 0.8021
# Epoch 12/15
# 1000/1000 [==============================] - 1487s 1s/step - loss: 0.3008 - accuracy: 0.9255 - val_loss: 1.4628 - val_accuracy: 0.7146
# Epoch 13/15
# 1000/1000 [==============================] - 1493s 1s/step - loss: 0.2602 - accuracy: 0.9363 - val_loss: 0.8118 - val_accuracy: 0.8469
# Epoch 14/15
# 1000/1000 [==============================] - 1426s 1s/step - loss: 0.1723 - accuracy: 0.9594 - val_loss: 2.5297 - val_accuracy: 0.7534
# Epoch 15/15
# 1000/1000 [==============================] - 1409s 1s/step - loss: 0.2029 - accuracy: 0.9504 - val_loss: 4.2473 - val_accuracy: 0.6562
# Saved model to disk

# %%
from keras import models
import numpy as np
from keras.preprocessing import image

test_image = image.load_img('/content/drive/My Drive/Colab Notebooks/Object Classification/Validation Set/Headphone/images (6).jpg', target_size = (224, 224))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
model = models.load_model('/content/drive/My Drive/Colab Notebooks/Object Classification/AlexNetAdammodel.h5')
result = model.predict(test_image)
print(result[0][2])
training_set.class_indices
if result[0][0] == 1:
    prediction = 'Headphone'
    print(prediction)
elif result[0][1] == 1:
    prediction = 'Keyboard'
    print(prediction)
elif result[0][2] == 1:
    prediction = 'Laptop'
    print(prediction)
elif result[0][3] == 1:
    prediction = 'Mobile'
    print(prediction)
else:
    prediction = 'Mouse'
    print(prediction)
# Out:
# 1.0
# Laptop

# %% [markdown]
# Test Whether GPU is working?

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import tensorflow as tf
tf.test.tpu_device_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-f4dcb5f51a3b> in <module>()
#       1 import tensorflow as tf
# ----> 2 tf.test.tpu_device_name()
#
# AttributeError: module 'tensorflow._api.v2.test' has no attribute 'tpu_device_name'

# %% [markdown]
# Which GPU we are using?

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4525774508651259468, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 4646176974541834230
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 13842703055481781806
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14648777152
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 3732169469368498949
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %% [markdown]
# RAM Information?

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13333556 kB
# MemFree:         9142956 kB
# MemAvailable:   11862616 kB
# Buffers:           79480 kB
# Cached:          2750336 kB
# SwapCached:            0 kB
# Active:          1216292 kB
# Inactive:        2553924 kB
# Active(anon):     866516 kB
# Inactive(anon):     8528 kB
# Active(file):     349776 kB
# Inactive(file):  2545396 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               672 kB
# Writeback:             0 kB
# AnonPages:        940400 kB
# Mapped:           687748 kB
# Shmem:              9140 kB
# Slab:             177408 kB
# SReclaimable:     130756 kB
# SUnreclaim:        46652 kB
# KernelStack:        4448 kB
# PageTables:         9256 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6666776 kB
# Committed_AS:    3517404 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# VmallocChunk:          0 kB
# Percpu:              920 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      195772 kB
# DirectMap2M:     7143424 kB
# DirectMap1G:     8388608 kB

# %% [markdown]
# CPU Info?

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs itlb_multihit
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs itlb_multihit
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# !nvidia smi
# Out:
# /bin/bash: nvidia: command not found
